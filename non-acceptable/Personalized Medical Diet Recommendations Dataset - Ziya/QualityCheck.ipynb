# %%
import pandas as pd

# Load dataset
df = pd.read_csv("Personalized_Diet_RecommendationsDC.csv")

# Define columns to exclude (non-numeric or irrelevant)
exclude_cols = ['User_ID'] if 'User_ID' in df.columns else []

# Select numeric columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
numeric_cols = [col for col in numeric_cols if col not in exclude_cols]

# Check target distribution
print("Target Distribution:")
print(df['Recommended_Meal_Plan'].value_counts(normalize=True))

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Check feature correlations with target (numeric columns only)
if numeric_cols:
    correlations = df[numeric_cols].corr()['Recommended_Meal_Plan'].sort_values(ascending=False)
    print("\nFeature Correlations with Target:")
    print(correlations.head(10), "\n", correlations.tail(10))
else:
    print("\nNo numeric columns found for correlation.")
# Out:
# Target Distribution:
# Recommended_Meal_Plan
# 2    0.2626
# 0    0.2510
# 1    0.2500
# 3    0.2364
# Name: proportion, dtype: float64
#
# Missing Values:
# Patient_ID                         0
# Age                                0
# Height_cm                          0
# Weight_kg                          0
# BMI                                0
# Blood_Pressure_Systolic            0
# Blood_Pressure_Diastolic           0
# Cholesterol_Level                  0
# Blood_Sugar_Level                  0
# Genetic_Risk_Factor                0
# Daily_Steps                        0
# Exercise_Frequency                 0
# Sleep_Hours                        0
# Alcohol_Consumption                0
# Smoking_Habit                      0
# Caloric_Intake                     0
# Protein_Intake                     0
# Carbohydrate_Intake                0
# Fat_Intake                         0
# Recommended_Meal_Plan              0
# Gender_Female                      0
# Gender_Male                        0
# Chronic_Disease_Diabetes           0
# Chronic_Disease_Heart_Disease      0
# Chronic_Disease_Hypertension       0
# Chronic_Disease_Obesity            0
# Allergies_Gluten_Intolerance       0
# Allergies_Lactose_Intolerance      0
# Allergies_Nut_Allergy              0
# Dietary_Habits_Keto                0
# Dietary_Habits_Vegan               0
# Dietary_Habits_Vegetarian          0
# Preferred_Cuisine_Asian            0
# Preferred_Cuisine_Indian           0
# Preferred_Cuisine_Mediterranean    0
# Preferred_Cuisine_Western          0
# Food_Aversions_Salty               0
# Food_Aversions_Spicy               0
# Food_Aversions_Sweet               0
# dtype: int64
#
# Feature Correlations with Target:
# Recommended_Meal_Plan            1.000000
# Food_Aversions_Salty             0.022748
# Allergies_Nut_Allergy            0.022046
# Age                              0.017087
# Carbohydrate_Intake              0.015611
# Dietary_Habits_Vegetarian        0.015409
# Allergies_Lactose_Intolerance    0.013035
# Chronic_Disease_Diabetes         0.010946
# Chronic_Disease_Heart_Disease    0.008196
# Exercise_Frequency               0.006755
# Name: Recommended_Meal_Plan, dtype: float64
#  Food_Aversions_Spicy              -0.005739
# Genetic_Risk_Factor               -0.005949
# Cholesterol_Level                 -0.007721
# Chronic_Disease_Hypertension      -0.008206
# Smoking_Habit                     -0.008799
# Chronic_Disease_Obesity           -0.011646
# Preferred_Cuisine_Mediterranean   -0.012771
# Blood_Pressure_Systolic           -0.022362
# Gender_Female                     -0.024839
# Dietary_Habits_Keto               -0.042065
# Name: Recommended_Meal_Plan, dtype: float64
